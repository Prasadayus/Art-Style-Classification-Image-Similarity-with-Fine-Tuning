# %%
import os
import pandas as pd
import numpy as np
import requests
import tensorflow as tf
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# %%
# Define file paths and create directories
DATA_DIR = 'nga_dataset'
IMAGE_DIR = os.path.join(DATA_DIR, 'images')
PROCESSED_DIR = os.path.join(DATA_DIR, 'processed')

os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(IMAGE_DIR, exist_ok=True)
os.makedirs(PROCESSED_DIR, exist_ok=True)

# Function to filter portrait paintings
def filter_portrait_paintings(objects_df, terms_df, images_df):
    # Standardize column names
    objects_df.columns = [col.lower() for col in objects_df.columns]
    images_df.columns = [col.lower() for col in images_df.columns]
    
    # Filter only paintings
    paintings = objects_df[objects_df['classification'].str.contains('painting', case=False, na=False)]
    print(f"Found {len(paintings)} paintings")

    # Identify portraits
    portraits = paintings[paintings['title'].str.contains('portrait|self portrait', case=False, na=False)]
    print(f"Found {len(portraits)} potential portraits by title")

    # Identify object ID column in images dataset
    id_column = 'depictstmsobjectid' if 'depictstmsobjectid' in images_df.columns else 'objectid'

    # Merge portraits with images
    portrait_images = pd.merge(portraits, images_df, left_on='objectid', right_on=id_column, how='inner')

    # Filter for primary view images
    if 'viewtype' in portrait_images.columns:
        portrait_images = portrait_images[portrait_images['viewtype'] == 'primary']

    print(f"Final dataset contains {len(portrait_images)} portrait paintings with images")
    return portrait_images

# Load datasets
objects = pd.read_csv(os.path.join(DATA_DIR, 'objects.csv'), low_memory=False)
images = pd.read_csv(os.path.join(DATA_DIR, 'published_images.csv'), low_memory=False)
terms = pd.read_csv(os.path.join(DATA_DIR, 'objects_terms.csv'), low_memory=False)

# Filter portraits
portrait_data = filter_portrait_paintings(objects, terms, images)

# %%
# Download and preprocess images
def download_and_preprocess_images(portrait_data, target_size=(224, 224), max_images=100):
    portrait_data = portrait_data.head(max_images)
    processed_data = []

    for idx, row in portrait_data.iterrows():
        object_id = row['objectid']
        base_url = row['iiifurl'].rstrip("/")  
        image_url = f"{base_url}/full/600,/0/default.jpg"
        
        image_filename = f"{object_id}.jpg"
        image_path = os.path.join(IMAGE_DIR, image_filename)

        if os.path.exists(image_path):
            print(f"Image {image_filename} already exists, skipping download.")
        else:
            try:
                response = requests.get(image_url, timeout=10)
                response.raise_for_status()
                
                img = Image.open(BytesIO(response.content))
                img.save(image_path)
                print(f"Saved image to {image_path}")
            except requests.exceptions.RequestException as e:
                print(f"Error downloading image for object {object_id}: {e}")
                continue
        
        processed_data.append({'objectID': object_id, 'title': row.get('title', 'Unknown'), 'image_path': image_path})

    return pd.DataFrame(processed_data)

processed_portraits = download_and_preprocess_images(portrait_data, max_images=None)
processed_portraits.to_csv(os.path.join(PROCESSED_DIR, 'portrait_dataset.csv'), index=False)

# %%
# Create TensorFlow dataset
def create_tf_dataset(df, target_size=(299, 299), batch_size=32):
    if df.empty:
        print("Error: Empty dataframe, cannot create dataset")
        return None

    def load_and_preprocess_image(image_path):
        img = tf.io.read_file(image_path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, target_size)
        img = img / 255.0
        return img

    dataset = tf.data.Dataset.from_tensor_slices((df['image_path'].values, df['objectID'].values))
    dataset = dataset.map(lambda x, y: (load_and_preprocess_image(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE)
    return dataset.batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

tf_dataset = create_tf_dataset(processed_portraits)

print("Dataset preparation complete!")
# Out:
# Found 4376 paintings
# Found 253 potential portraits by title
# Final dataset contains 197 portrait paintings with images
# Image 19.jpg already exists, skipping download.
# Image 25.jpg already exists, skipping download.
# Image 38.jpg already exists, skipping download.
# Image 49.jpg already exists, skipping download.
# Image 59.jpg already exists, skipping download.
# Image 89.jpg already exists, skipping download.
# Image 1167.jpg already exists, skipping download.
# Image 1206.jpg already exists, skipping download.
# Image 1207.jpg already exists, skipping download.
# Image 1235.jpg already exists, skipping download.
# Image 37636.jpg already exists, skipping download.
# Image 46496.jpg already exists, skipping download.
# Image 46518.jpg already exists, skipping download.
# Image 46628.jpg already exists, skipping download.
# Image 50293.jpg already exists, skipping download.
# Image 50722.jpg already exists, skipping download.
# Image 51096.jpg already exists, skipping download.
# Image 52257.jpg already exists, skipping download.
# Image 166431.jpg already exists, skipping download.
# Image 205907.jpg already exists, skipping download.
# Image 224391.jpg already exists, skipping download.
# Image 1095.jpg already exists, skipping download.
# Image 1131.jpg already exists, skipping download.
# Image 3209.jpg already exists, skipping download.
# Image 34085.jpg already exists, skipping download.
# Image 34070.jpg already exists, skipping download.
# Image 34072.jpg already exists, skipping download.
# Image 34083.jpg already exists, skipping download.
# Image 34092.jpg already exists, skipping download.
# Image 34096.jpg already exists, skipping download.
# Image 34117.jpg already exists, skipping download.
# Image 34130.jpg already exists, skipping download.
# Image 34135.jpg already exists, skipping download.
# Image 34146.jpg already exists, skipping download.
# Image 34148.jpg already exists, skipping download.
# Image 42444.jpg already exists, skipping download.
# Image 42485.jpg already exists, skipping download.
# Image 42486.jpg already exists, skipping download.
# Image 42917.jpg already exists, skipping download.
# Image 43445.jpg already exists, skipping download.
# Image 46025.jpg already exists, skipping download.
# Image 46587.jpg already exists, skipping download.
# Image 46691.jpg already exists, skipping download.
# Image 52380.jpg already exists, skipping download.
# Image 56231.jpg already exists, skipping download.
# Image 59907.jpg already exists, skipping download.
# Image 65606.jpg already exists, skipping download.
# Image 67384.jpg already exists, skipping download.
# Image 67401.jpg already exists, skipping download.
# Image 92215.jpg already exists, skipping download.
# Image 92991.jpg already exists, skipping download.
# Image 98594.jpg already exists, skipping download.
# Image 98593.jpg already exists, skipping download.
# Image 98467.jpg already exists, skipping download.
# Image 100870.jpg already exists, skipping download.
# Image 111757.jpg already exists, skipping download.
# Image 121105.jpg already exists, skipping download.
# Image 154543.jpg already exists, skipping download.
# Image 171260.jpg already exists, skipping download.
# Image 171263.jpg already exists, skipping download.
# Image 176359.jpg already exists, skipping download.
# Image 177526.jpg already exists, skipping download.
# Image 177911.jpg already exists, skipping download.
# Image 204747.jpg already exists, skipping download.
# Image 206066.jpg already exists, skipping download.
# Image 220938.jpg already exists, skipping download.
# Image 223873.jpg already exists, skipping download.
# Image 228065.jpg already exists, skipping download.
# Image 228852.jpg already exists, skipping download.
# Image 16.jpg already exists, skipping download.
# Image 22.jpg already exists, skipping download.
# Image 75.jpg already exists, skipping download.
# Image 36.jpg already exists, skipping download.
# Image 44.jpg already exists, skipping download.
# Image 53.jpg already exists, skipping download.
# Image 73.jpg already exists, skipping download.
# Image 74.jpg already exists, skipping download.
# Image 78.jpg already exists, skipping download.
# Image 239.jpg already exists, skipping download.
# Image 172.jpg already exists, skipping download.
# Image 243.jpg already exists, skipping download.
# Image 320.jpg already exists, skipping download.
# Image 323.jpg already exists, skipping download.
# Image 371.jpg already exists, skipping download.
# Image 395.jpg already exists, skipping download.
# Image 398.jpg already exists, skipping download.
# Image 399.jpg already exists, skipping download.
# Image 406.jpg already exists, skipping download.
# Image 437.jpg already exists, skipping download.
# Image 497.jpg already exists, skipping download.
# Image 499.jpg already exists, skipping download.
# Image 501.jpg already exists, skipping download.
# Image 565.jpg already exists, skipping download.
# Image 570.jpg already exists, skipping download.
# Image 573.jpg already exists, skipping download.
# Image 1177.jpg already exists, skipping download.
# Image 1099.jpg already exists, skipping download.
# Image 1102.jpg already exists, skipping download.
# Image 1168.jpg already exists, skipping download.
# Image 1186.jpg already exists, skipping download.
# Saved image to nga_dataset\images\1190.jpg
# Saved image to nga_dataset\images\1209.jpg
# Saved image to nga_dataset\images\1208.jpg
# Saved image to nga_dataset\images\3199.jpg
# Saved image to nga_dataset\images\3202.jpg
# Saved image to nga_dataset\images\12201.jpg
# Saved image to nga_dataset\images\12208.jpg
# Saved image to nga_dataset\images\32682.jpg
# Saved image to nga_dataset\images\32695.jpg
# Saved image to nga_dataset\images\33246.jpg
# Saved image to nga_dataset\images\33255.jpg
# Saved image to nga_dataset\images\33752.jpg
# Saved image to nga_dataset\images\34049.jpg
# Saved image to nga_dataset\images\34079.jpg
# Saved image to nga_dataset\images\34081.jpg
# Saved image to nga_dataset\images\34082.jpg
# Saved image to nga_dataset\images\34102.jpg
# Saved image to nga_dataset\images\34106.jpg
# Saved image to nga_dataset\images\34124.jpg
# Saved image to nga_dataset\images\34147.jpg
# Saved image to nga_dataset\images\34136.jpg
# Saved image to nga_dataset\images\34143.jpg
# Saved image to nga_dataset\images\34160.jpg
# Saved image to nga_dataset\images\34163.jpg
# Saved image to nga_dataset\images\41584.jpg
# Saved image to nga_dataset\images\41600.jpg
# Saved image to nga_dataset\images\41591.jpg
# Saved image to nga_dataset\images\41681.jpg
# Saved image to nga_dataset\images\41686.jpg
# Error downloading image for object 41689: ('Connection broken: IncompleteRead(2732 bytes read, 7508 more expected)', IncompleteRead(2732 bytes read, 7508 more expected))
# Saved image to nga_dataset\images\41726.jpg
# Saved image to nga_dataset\images\42284.jpg
# Saved image to nga_dataset\images\42398.jpg
# Saved image to nga_dataset\images\42411.jpg
# Saved image to nga_dataset\images\42425.jpg
# Error downloading image for object 42911: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Saved image to nga_dataset\images\43446.jpg
# Error downloading image for object 43515: ('Connection broken: IncompleteRead(6055 bytes read, 4185 more expected)', IncompleteRead(6055 bytes read, 4185 more expected))
# Saved image to nga_dataset\images\43597.jpg
# Saved image to nga_dataset\images\43626.jpg
# Saved image to nga_dataset\images\46440.jpg
# Saved image to nga_dataset\images\46153.jpg
# Saved image to nga_dataset\images\45886.jpg
# Saved image to nga_dataset\images\45887.jpg
# Saved image to nga_dataset\images\46109.jpg
# Saved image to nga_dataset\images\45879.jpg
# Saved image to nga_dataset\images\46052.jpg
# Saved image to nga_dataset\images\46063.jpg
# Saved image to nga_dataset\images\46158.jpg
# Saved image to nga_dataset\images\46110.jpg
# Saved image to nga_dataset\images\46095.jpg
# Saved image to nga_dataset\images\46117.jpg
# Saved image to nga_dataset\images\46120.jpg
# Saved image to nga_dataset\images\46125.jpg
# Saved image to nga_dataset\images\46137.jpg
# Saved image to nga_dataset\images\46156.jpg
# Saved image to nga_dataset\images\46165.jpg
# Saved image to nga_dataset\images\46178.jpg
# Saved image to nga_dataset\images\46490.jpg
# Saved image to nga_dataset\images\46482.jpg
# Saved image to nga_dataset\images\46484.jpg
# Saved image to nga_dataset\images\46500.jpg
# Saved image to nga_dataset\images\46593.jpg
# Saved image to nga_dataset\images\47181.jpg
# Saved image to nga_dataset\images\50492.jpg
# Saved image to nga_dataset\images\50823.jpg
# Saved image to nga_dataset\images\50824.jpg
# Saved image to nga_dataset\images\59893.jpg
# Saved image to nga_dataset\images\59929.jpg
# Saved image to nga_dataset\images\59930.jpg
# Saved image to nga_dataset\images\66418.jpg
# Saved image to nga_dataset\images\72072.jpg
# Saved image to nga_dataset\images\92994.jpg
# Saved image to nga_dataset\images\92996.jpg
# Saved image to nga_dataset\images\93000.jpg
# Saved image to nga_dataset\images\108661.jpg
# Saved image to nga_dataset\images\118611.jpg
# Saved image to nga_dataset\images\121137.jpg
# Saved image to nga_dataset\images\128004.jpg
# Saved image to nga_dataset\images\129282.jpg
# Saved image to nga_dataset\images\131994.jpg
# Saved image to nga_dataset\images\134427.jpg
# Saved image to nga_dataset\images\158097.jpg
# Saved image to nga_dataset\images\176558.jpg
# Saved image to nga_dataset\images\176888.jpg
# Saved image to nga_dataset\images\177073.jpg
# Saved image to nga_dataset\images\195727.jpg
# Saved image to nga_dataset\images\204092.jpg
# Saved image to nga_dataset\images\21.jpg
# Saved image to nga_dataset\images\51.jpg
# Saved image to nga_dataset\images\79.jpg
# Saved image to nga_dataset\images\1121.jpg
# Saved image to nga_dataset\images\37003.jpg
# Saved image to nga_dataset\images\39729.jpg
# Saved image to nga_dataset\images\46620.jpg
# Saved image to nga_dataset\images\46625.jpg
# Saved image to nga_dataset\images\106382.jpg
# ✅ Dataset preparation complete!
